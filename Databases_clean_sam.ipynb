# %% [markdown]
# # Final Project Data : Exploratory Analysis

# %%
# Add our dependencies.
import csv
import os

# %%
# Add our dependencies.
import pandas as pd
import numpy as np
import sqlalchemy as sql
from sqlalchemy import create_engine
import psycopg2
from sqlalchemy import MetaData

# %% [markdown]
# # Loading files

# %%
county_elections_to_load = 'https://dataanalyticsfinalproject2022.s3.us-east-2.amazonaws.com/Resources/countypres_2000-2020.csv'
debt_to_load= "https://dataanalyticsfinalproject2022.s3.us-east-2.amazonaws.com/Resources/county_dia_auto_+7+Jun+2022.csv"
pop_to_load= "https://dataanalyticsfinalproject2022.s3.us-east-2.amazonaws.com/Resources/co-est2019-alldata.csv"

# %% [markdown]
# # Postgres Connection

# %%
engine = sql.create_engine('postgresql://ElectionTeam:finalproject@final-data-project.cxtxzq2kyq9u.us-east-1.rds.amazonaws.com:5432/election_data')

# %%
engine.table_names()
# Out:
# []

# %% [markdown]
# # DEBT BY COUNTY DATABASE

# %%
debt_data_df=pd.read_csv(debt_to_load, header=1)
debt_data_df.head()
# Out:
#                       NAME  GEOID state_name  \
# 0  Autauga County, Alabama   1001    Alabama
# 1  Baldwin County, Alabama   1003    Alabama
# 2  Barbour County, Alabama   1005    Alabama
# 3     Bibb County, Alabama   1007    Alabama
# 4   Blount County, Alabama   1009    Alabama
#
#   Auto/Retail Debt Delinquency Rate, All  \
# 0                               .0634218
# 1                               .0428429
# 2                               .0868167
# 3                               .1048689
# 4                               .0407876
#
#   Auto/Retail Debt Delinquency Rate, Communities of Color  \
# 0                                               n/a*
# 1                                              n/a**
# 2                                               n/a*
# 3                                              n/a**
# 4                                               n/a*
#
#   Auto/Retail Debt Delinquency Rate, Majority White Communities  \
# ...

# %%
debt_data_df.count()
# Out:
# NAME                                                                 3137
# GEOID                                                                3137
# state_name                                                           3137
# Auto/Retail Debt Delinquency Rate, All                               3137
# Auto/Retail Debt Delinquency Rate, Communities of Color              3137
# Auto/Retail Debt Delinquency Rate, Majority White Communities        3137
# Share of Subprime Consumers with Auto/Retail Delinquencies, All      3137
# Share of Near-Prime Consumers with Auto/Retail Delinquencies, All    3137
# Share of Prime Consumers with Auto/Retail Delinquencies, All         3137
# Share with Open Auto Debt, All                                       3137
# Share with Open Auto Debt, Communities of Color                      3137
# Share with Open Auto Debt, Majority White Communities                3137
# Share with Open Auto/Retail Debt, All                                3137
# ...

# %%
debt_data_df.dtypes
# Out:
# NAME                                                                  object
# GEOID                                                                  int64
# state_name                                                            object
# Auto/Retail Debt Delinquency Rate, All                                object
# Auto/Retail Debt Delinquency Rate, Communities of Color               object
# Auto/Retail Debt Delinquency Rate, Majority White Communities         object
# Share of Subprime Consumers with Auto/Retail Delinquencies, All       object
# Share of Near-Prime Consumers with Auto/Retail Delinquencies, All     object
# Share of Prime Consumers with Auto/Retail Delinquencies, All          object
# Share with Open Auto Debt, All                                        object
# Share with Open Auto Debt, Communities of Color                       object
# Share with Open Auto Debt, Majority White Communities                 object
# ...

# %%
new_column_order= [
                         "state_name",
                         'NAME',
                         "Share with Open Auto Debt, All",
                         "Share with Open Auto Debt, Communities of Color",
                         "Share with Open Auto Debt, Majority White Communities",
                         "Average household income, 2019 (ACS)",
                         "Average non-white household income, 2019 (ACS)",
                         "Average white, non-Hispanic household income, 2019 (ACS)"]
debt_data_df=debt_data_df[new_column_order]
debt_data_df.head()
# Out:
#   state_name                     NAME Share with Open Auto Debt, All  \
# 0    Alabama  Autauga County, Alabama                       .2623955
# 1    Alabama  Baldwin County, Alabama                         .33154
# 2    Alabama  Barbour County, Alabama                       .2787958
# 3    Alabama     Bibb County, Alabama                       .3047619
# 4    Alabama   Blount County, Alabama                       .2988116
#
#   Share with Open Auto Debt, Communities of Color  \
# 0                                            n/a*
# 1                                           n/a**
# 2                                        .2435897
# 3                                           n/a**
# 4                                            n/a*
#
#   Share with Open Auto Debt, Majority White Communities  \
# 0                                           .2649472
# 1                                           .3327853
# 2                                           .3454545
# ...

# %%
len(debt_data_df)
# Out:
# 3137

# %%
debt_data_df.isnull().count()
# Out:
# state_name                                                  3137
# NAME                                                        3137
# Share with Open Auto Debt, All                              3137
# Share with Open Auto Debt, Communities of Color             3137
# Share with Open Auto Debt, Majority White Communities       3137
# Average household income, 2019 (ACS)                        3137
# Average non-white household income, 2019 (ACS)              3137
# Average white, non-Hispanic household income, 2019 (ACS)    3137
# dtype: int64

# %%
debt_df = debt_data_df[['state_name', 'NAME','Share with Open Auto Debt, All', 'Share with Open Auto Debt, Communities of Color', 'Share with Open Auto Debt, Majority White Communities', 'Average household income, 2019 (ACS)', 'Average non-white household income, 2019 (ACS)', 'Average white, non-Hispanic household income, 2019 (ACS)']]
debt_df
# Out:
#      state_name                          NAME Share with Open Auto Debt, All  \
# 0       Alabama       Autauga County, Alabama                       .2623955
# 1       Alabama       Baldwin County, Alabama                         .33154
# 2       Alabama       Barbour County, Alabama                       .2787958
# 3       Alabama          Bibb County, Alabama                       .3047619
# 4       Alabama        Blount County, Alabama                       .2988116
# 5       Alabama       Bullock County, Alabama                       .2777778
# 6       Alabama        Butler County, Alabama                       .2351047
# 7       Alabama       Calhoun County, Alabama                       .2871537
# 8       Alabama      Chambers County, Alabama                       .2857143
# 9       Alabama      Cherokee County, Alabama                       .3003755
# 10      Alabama       Chilton County, Alabama                       .2815014
# ...

# %%
county_name_df= debt_df['NAME'].str.split(",",expand=True)
county_name_df
# Out:
#                        0           1
# 0         Autauga County     Alabama
# 1         Baldwin County     Alabama
# 2         Barbour County     Alabama
# 3            Bibb County     Alabama
# 4          Blount County     Alabama
# 5         Bullock County     Alabama
# 6          Butler County     Alabama
# 7         Calhoun County     Alabama
# 8        Chambers County     Alabama
# 9        Cherokee County     Alabama
# 10        Chilton County     Alabama
# 11        Choctaw County     Alabama
# 12         Clarke County     Alabama
# 13           Clay County     Alabama
# 14       Cleburne County     Alabama
# 15         Coffee County     Alabama
# 16        Colbert County     Alabama
# 17        Conecuh County     Alabama
# 18          Coosa County     Alabama
# 19      Covington County     Alabama
# 20       Crenshaw County     Alabama
# 21        Cullman County     Alabama
# 22           Dale County     Alabama
# 23         Dallas County     Alabama
# ...

# %%
debt_df['county_name'] = debt_df['NAME'].str.split(' ').str[0]
debt_df['county_name'] = debt_df['county_name'].str.upper()

# %%
debt_df.head()
# Out:
#   state_name                     NAME Share with Open Auto Debt, All  \
# 0    Alabama  Autauga County, Alabama                       .2623955
# 1    Alabama  Baldwin County, Alabama                         .33154
# 2    Alabama  Barbour County, Alabama                       .2787958
# 3    Alabama     Bibb County, Alabama                       .3047619
# 4    Alabama   Blount County, Alabama                       .2988116
#
#   Share with Open Auto Debt, Communities of Color  \
# 0                                            n/a*
# 1                                           n/a**
# 2                                        .2435897
# 3                                           n/a**
# 4                                            n/a*
#
#   Share with Open Auto Debt, Majority White Communities  \
# 0                                           .2649472
# 1                                           .3327853
# 2                                           .3454545
# ...

# %%
new_column_order= [
                         "state_name",
                         "county_name",
                         "Share with Open Auto Debt, All",
                         "Share with Open Auto Debt, Communities of Color",
                         "Share with Open Auto Debt, Majority White Communities",
                         "Average household income, 2019 (ACS)",
                         "Average non-white household income, 2019 (ACS)",
                         "Average white, non-Hispanic household income, 2019 (ACS)"]
debt_df=debt_df[new_column_order]
debt_df
# Out:
#      state_name county_name Share with Open Auto Debt, All  \
# 0       Alabama     AUTAUGA                       .2623955
# 1       Alabama     BALDWIN                         .33154
# 2       Alabama     BARBOUR                       .2787958
# 3       Alabama        BIBB                       .3047619
# 4       Alabama      BLOUNT                       .2988116
# 5       Alabama     BULLOCK                       .2777778
# 6       Alabama      BUTLER                       .2351047
# 7       Alabama     CALHOUN                       .2871537
# 8       Alabama    CHAMBERS                       .2857143
# 9       Alabama    CHEROKEE                       .3003755
# 10      Alabama     CHILTON                       .2815014
# 11      Alabama     CHOCTAW                       .2865014
# 12      Alabama      CLARKE                       .3132023
# 13      Alabama        CLAY                       .2653061
# 14      Alabama    CLEBURNE                       .3225108
# ...

# %%
debt_df.rename({"Share with Open Auto Debt, All": "Debt_All",
                         "Share with Open Auto Debt, Communities of Color": "Debt_Communities_Color",
                         "Share with Open Auto Debt, Majority White Communities": "Debt_Majorities_White",
                         "Average household income, 2019 (ACS)":"Avg_Household_Income_All",
                         "Average non-white household income, 2019 (ACS)": "Avg_Non_White_Income",
                         "Average white, non-Hispanic household income, 2019 (ACS)":  "Avg_Non_Hispanic"
                       }, axis=1, inplace=True)
debt_df
# Out:
# C:\Users\alelo\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#      state_name county_name  Debt_All Debt_Communities_Color  \
# 0       Alabama     AUTAUGA  .2623955                   n/a*
# 1       Alabama     BALDWIN    .33154                  n/a**
# 2       Alabama     BARBOUR  .2787958               .2435897
# 3       Alabama        BIBB  .3047619                  n/a**
# 4       Alabama      BLOUNT  .2988116                   n/a*
# 5       Alabama     BULLOCK  .2777778               .2727273
# 6       Alabama      BUTLER  .2351047                   n/a*
# 7       Alabama     CALHOUN  .2871537                  n/a**
# 8       Alabama    CHAMBERS  .2857143                   n/a*
# ...

# %%
debt_clean_df1=debt_df.replace(['n/a*'], 49)
debt_clean_df1
# Out:
#      state_name county_name  Debt_All Debt_Communities_Color  \
# 0       Alabama     AUTAUGA  .2623955                     49
# 1       Alabama     BALDWIN    .33154                  n/a**
# 2       Alabama     BARBOUR  .2787958               .2435897
# 3       Alabama        BIBB  .3047619                  n/a**
# 4       Alabama      BLOUNT  .2988116                     49
# 5       Alabama     BULLOCK  .2777778               .2727273
# 6       Alabama      BUTLER  .2351047                     49
# 7       Alabama     CALHOUN  .2871537                  n/a**
# 8       Alabama    CHAMBERS  .2857143                     49
# 9       Alabama    CHEROKEE  .3003755                  n/a**
# 10      Alabama     CHILTON  .2815014                     49
# 11      Alabama     CHOCTAW  .2865014                .287037
# 12      Alabama      CLARKE  .3132023                     49
# 13      Alabama        CLAY  .2653061                  n/a**
# ...

# %%
debt_clean_df=debt_clean_df1.replace(['n/a**'], 49)
debt_clean_df
# Out:
#      state_name county_name  Debt_All Debt_Communities_Color  \
# 0       Alabama     AUTAUGA  .2623955                     49
# 1       Alabama     BALDWIN    .33154                     49
# 2       Alabama     BARBOUR  .2787958               .2435897
# 3       Alabama        BIBB  .3047619                     49
# 4       Alabama      BLOUNT  .2988116                     49
# 5       Alabama     BULLOCK  .2777778               .2727273
# 6       Alabama      BUTLER  .2351047                     49
# 7       Alabama     CALHOUN  .2871537                     49
# 8       Alabama    CHAMBERS  .2857143                     49
# 9       Alabama    CHEROKEE  .3003755                     49
# 10      Alabama     CHILTON  .2815014                     49
# 11      Alabama     CHOCTAW  .2865014                .287037
# 12      Alabama      CLARKE  .3132023                     49
# 13      Alabama        CLAY  .2653061                     49
# ...

# %%
debt_clean_df3= debt_clean_df.drop_duplicates(subset= 'county_name', keep='last')

# %%
debt_clean_df3[debt_clean_df3['county_name']== 'ALEUTIANS']
# Out:
#    state_name county_name  Debt_All Debt_Communities_Color  \
# 68     Alaska   ALEUTIANS  .1038961               .1038961
#
#    Debt_Majorities_White  Avg_Household_Income_All Avg_Non_White_Income  \
# 68                    49                    101964                86979
#
#     Avg_Non_Hispanic
# 68            133787

# %%
debt_clean_df3
# Out:
#      state_name        county_name  Debt_All Debt_Communities_Color  \
# 0       Alabama            AUTAUGA  .2623955                     49
# 5       Alabama            BULLOCK  .2777778               .2727273
# 10      Alabama            CHILTON  .2815014                     49
# 16      Alabama            COLBERT  .2895472                     49
# 17      Alabama            CONECUH  .3046358               .3030303
# 18      Alabama              COOSA  .2738853                     49
# 20      Alabama           CRENSHAW  .3108911                     49
# 21      Alabama            CULLMAN  .3008757                     49
# 22      Alabama               DALE  .3198353                     49
# 27      Alabama             ETOWAH   .281717                     49
# 30      Alabama             GENEVA  .3071749                     49
# 45      Alabama            MARENGO  .3255426               .3473684
# 48      Alabama             MOBILE  .2901475               .2586858
# ...

# %%
debt_clean_df3.to_csv("debt_clean_vf.csv", index=False)

# %%
debt_clean_df3.to_sql('debt_clean_vf', con = engine, index=False, if_exists = 'replace')

# %% [markdown]
# # COUNTY VOTES DATABASE

# %%
county_elections_df = pd.read_csv(county_elections_to_load)
county_elections_df.head()
# Out:
#    year    state state_po county_name  county_fips        office  \
# 0  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 1  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 2  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 3  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 4  2000  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
#
#         candidate       party  candidatevotes  totalvotes   version   mode
# 0         AL GORE    DEMOCRAT            4942       17208  20220315  TOTAL
# 1  GEORGE W. BUSH  REPUBLICAN           11993       17208  20220315  TOTAL
# 2     RALPH NADER       GREEN             160       17208  20220315  TOTAL
# 3           OTHER       OTHER             113       17208  20220315  TOTAL
# 4         AL GORE    DEMOCRAT           13997       56480  20220315  TOTAL

# %%
county_elections_df.count()
# Out:
# year              72617
# state             72617
# state_po          72617
# county_name       72617
# county_fips       72560
# office            72617
# candidate         72617
# party             72617
# candidatevotes    72617
# totalvotes        72617
# version           72617
# mode              72617
# dtype: int64

# %%
county_elections_df.isnull().count()
# Out:
# year              72617
# state             72617
# state_po          72617
# county_name       72617
# county_fips       72617
# office            72617
# candidate         72617
# party             72617
# candidatevotes    72617
# totalvotes        72617
# version           72617
# mode              72617
# dtype: int64

# %%
county_elections_df.dtypes
# Out:
# year                int64
# state              object
# state_po           object
# county_name        object
# county_fips       float64
# office             object
# candidate          object
# party              object
# candidatevotes      int64
# totalvotes          int64
# version             int64
# mode               object
# dtype: object

# %%
county_votes_df.state.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-f0def0f5d9de> in <module>
# ----> 1 county_votes_df.state.value_counts()
#
# NameError: name 'county_votes_df' is not defined

# %%
len(county_elections_df.county_name.unique())

# %%
len(county_elections_df.state.unique())
# Out:
# 51

# %%
county_elections_df.year.value_counts()
# Out:
# 2020    22093
# 2000    12628
# 2016     9474
# 2012     9474
# 2008     9474
# 2004     9474
# Name: year, dtype: int64

# %%
county_elections_df.party.value_counts()
# Out:
# REPUBLICAN     20906
# DEMOCRAT       20906
# OTHER          19815
# GREEN           6035
# LIBERTARIAN     4955
# Name: party, dtype: int64

# %%
county_votes_2020_df=county_elections_df[county_elections_df['year']==2020]
county_votes_2020_df.head()
# Out:
#        year    state state_po county_name  county_fips        office  \
# 50524  2020  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 50525  2020  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 50526  2020  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 50527  2020  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
# 50528  2020  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
#
#                candidate       party  candidatevotes  totalvotes   version  \
# 50524  JOSEPH R BIDEN JR    DEMOCRAT            7503       27770  20220315
# 50525              OTHER       OTHER             429       27770  20220315
# 50526     DONALD J TRUMP  REPUBLICAN           19838       27770  20220315
# 50527  JOSEPH R BIDEN JR    DEMOCRAT           24578      109679  20220315
# 50528              OTHER       OTHER            1557      109679  20220315
#
#         mode
# 50524  TOTAL
# 50525  TOTAL
# 50526  TOTAL
# 50527  TOTAL
# 50528  TOTAL

# %%
len(county_votes_2020_df.state.unique())
# Out:
# 51

# %%
len(county_votes_2020_df.county_name.unique())
# Out:
# 1865

# %%
county_votes_2020_df.party.value_counts()
# Out:
# REPUBLICAN     5117
# DEMOCRAT       5117
# LIBERTARIAN    4955
# OTHER          4026
# GREEN          2878
# Name: party, dtype: int64

# %%
county_votes_2020_df.party.value_counts()
# Out:
# REPUBLICAN     5117
# DEMOCRAT       5117
# LIBERTARIAN    4955
# OTHER          4026
# GREEN          2878
# Name: party, dtype: int64

# %% [markdown]
# ### Elections results by county

# %%
county_votes_2020_df['party'].unique()
# Out:
# array(['DEMOCRAT', 'OTHER', 'REPUBLICAN', 'GREEN', 'LIBERTARIAN'],
#       dtype=object)

# %%
county_votes_2020_df[county_votes_2020_df['county_fips']==4001]
# Out:
#        year    state state_po county_name  county_fips        office  \
# 50930  2020  ARIZONA       AZ      APACHE       4001.0  US PRESIDENT
# 50931  2020  ARIZONA       AZ      APACHE       4001.0  US PRESIDENT
# 50932  2020  ARIZONA       AZ      APACHE       4001.0  US PRESIDENT
# 50933  2020  ARIZONA       AZ      APACHE       4001.0  US PRESIDENT
# 50934  2020  ARIZONA       AZ      APACHE       4001.0  US PRESIDENT
# 50935  2020  ARIZONA       AZ      APACHE       4001.0  US PRESIDENT
# 50936  2020  ARIZONA       AZ      APACHE       4001.0  US PRESIDENT
# 50937  2020  ARIZONA       AZ      APACHE       4001.0  US PRESIDENT
# 50938  2020  ARIZONA       AZ      APACHE       4001.0  US PRESIDENT
# 50939  2020  ARIZONA       AZ      APACHE       4001.0  US PRESIDENT
# 50940  2020  ARIZONA       AZ      APACHE       4001.0  US PRESIDENT
# 50941  2020  ARIZONA       AZ      APACHE       4001.0  US PRESIDENT
# 50942  2020  ARIZONA       AZ      APACHE       4001.0  US PRESIDENT
# ...

# %%
elections_df1 =county_votes_2020_df.drop(columns=['year','state','state_po','office','version','mode'])
elections_df1
# Out:
#       county_name  county_fips          candidate        party  \
# 50524     AUTAUGA       1001.0  JOSEPH R BIDEN JR     DEMOCRAT
# 50525     AUTAUGA       1001.0              OTHER        OTHER
# 50526     AUTAUGA       1001.0     DONALD J TRUMP   REPUBLICAN
# 50527     BALDWIN       1003.0  JOSEPH R BIDEN JR     DEMOCRAT
# 50528     BALDWIN       1003.0              OTHER        OTHER
# 50529     BALDWIN       1003.0     DONALD J TRUMP   REPUBLICAN
# 50530     BARBOUR       1005.0  JOSEPH R BIDEN JR     DEMOCRAT
# 50531     BARBOUR       1005.0              OTHER        OTHER
# 50532     BARBOUR       1005.0     DONALD J TRUMP   REPUBLICAN
# 50533        BIBB       1007.0  JOSEPH R BIDEN JR     DEMOCRAT
# 50534        BIBB       1007.0              OTHER        OTHER
# 50535        BIBB       1007.0     DONALD J TRUMP   REPUBLICAN
# 50536      BLOUNT       1009.0  JOSEPH R BIDEN JR     DEMOCRAT
# 50537      BLOUNT       1009.0              OTHER        OTHER
# ...

# %%
df=elections_df1.pivot_table(index='county_fips', columns = 'party', values = 'candidatevotes', aggfunc='sum')

# %%
df
# Out:
# party        DEMOCRAT  GREEN  LIBERTARIAN   OTHER  REPUBLICAN
# county_fips
# 1001.0         7503.0    NaN          NaN   429.0     19838.0
# 1003.0        24578.0    NaN          NaN  1557.0     83544.0
# 1005.0         4816.0    NaN          NaN    80.0      5622.0
# 1007.0         1986.0    NaN          NaN    84.0      7525.0
# 1009.0         2640.0    NaN          NaN   237.0     24711.0
# 1011.0         3446.0    NaN          NaN    21.0      1146.0
# 1013.0         3965.0    NaN          NaN    65.0      5458.0
# 1015.0        15216.0    NaN          NaN   666.0     35101.0
# 1017.0         6365.0    NaN          NaN   166.0      8753.0
# 1019.0         1624.0    NaN          NaN    94.0     10583.0
# 1021.0         3073.0    NaN          NaN   152.0     16085.0
# 1023.0         3127.0    NaN          NaN    41.0      4296.0
# 1025.0         5755.0    NaN          NaN    56.0      7324.0
# 1027.0         1267.0    NaN          NaN    62.0      5601.0
# ...

# %%
df.dtypes
# Out:
# party
# DEMOCRAT       float64
# GREEN          float64
# LIBERTARIAN    float64
# OTHER          float64
# REPUBLICAN     float64
# dtype: object

# %%
df2=elections_df1.pivot_table(index='county_name', columns = 'party', values = 'candidatevotes', aggfunc='sum')
df2
# Out:
# party            DEMOCRAT   GREEN  LIBERTARIAN   OTHER  REPUBLICAN
# county_name
# ABBEVILLE          4101.0    23.0         88.0     6.0      8215.0
# ACADIA             5443.0     NaN        241.0   145.0     22596.0
# ACCOMACK           7578.0     NaN        188.0    24.0      9172.0
# ADA              120539.0     NaN       5310.0  2841.0    130699.0
# ADAIR              7687.0    47.0        314.0   140.0     22196.0
# ADAMS            186146.0   876.0       6013.0  2719.0    209463.0
# ADDISON           15089.0    69.0        248.0   638.0      6567.0
# AIKEN             32275.0   274.0        982.0    65.0     51589.0
# AITKIN             3607.0    24.0         55.0    81.0      6258.0
# ALACHUA           89704.0   302.0       1390.0   236.0     50972.0
# ALAMANCE          38825.0   223.0        686.0   301.0     46056.0
# ALAMEDA          617659.0  4664.0       6295.0  5143.0    136309.0
# ALAMOSA            3759.0    23.0         90.0   123.0      3813.0
# ...

# %%
df2.fillna(0, inplace=True)
df2
# Out:
# party        DEMOCRAT  GREEN  LIBERTARIAN   OTHER  REPUBLICAN
# county_name
# ABBEVILLE      4101.0   23.0         88.0     6.0      8215.0
# ACADIA         5443.0    0.0        241.0   145.0     22596.0
# ACCOMACK       7578.0    0.0        188.0    24.0      9172.0
# ADA          120539.0    0.0       5310.0  2841.0    130699.0
# ADAIR          7687.0   47.0        314.0   140.0     22196.0
# ...               ...    ...          ...     ...         ...
# YUBA          11230.0  124.0        510.0   256.0     17676.0
# YUMA          32995.0    2.0       1189.0    35.0     40641.0
# ZAPATA         1826.0    4.0         11.0     0.0      2033.0
# ZAVALA         2864.0   12.0         13.0     0.0      1490.0
# ZIEBACH         481.0    0.0         21.0     0.0       404.0
#
# [1865 rows x 5 columns]

# %%
df2.dtypes
# Out:
# party
# DEMOCRAT       float64
# GREEN          float64
# LIBERTARIAN    float64
# OTHER          float64
# REPUBLICAN     float64
# dtype: object

# %%
#Creating the winner column in order to know which party won
df2['WINNER'] = np.where((df2['DEMOCRAT'] > df2['REPUBLICAN']),1 , 0)

# %%
df2
# Out:
# party            DEMOCRAT   GREEN  LIBERTARIAN   OTHER  REPUBLICAN  WINNER
# county_name
# ABBEVILLE          4101.0    23.0         88.0     6.0      8215.0       0
# ACADIA             5443.0     NaN        241.0   145.0     22596.0       0
# ACCOMACK           7578.0     NaN        188.0    24.0      9172.0       0
# ADA              120539.0     NaN       5310.0  2841.0    130699.0       0
# ADAIR              7687.0    47.0        314.0   140.0     22196.0       0
# ADAMS            186146.0   876.0       6013.0  2719.0    209463.0       0
# ADDISON           15089.0    69.0        248.0   638.0      6567.0       1
# AIKEN             32275.0   274.0        982.0    65.0     51589.0       0
# AITKIN             3607.0    24.0         55.0    81.0      6258.0       0
# ALACHUA           89704.0   302.0       1390.0   236.0     50972.0       1
# ALAMANCE          38825.0   223.0        686.0   301.0     46056.0       0
# ...

# %%
df2.to_csv("elections2020_clean.csv")

# %%
df2.dtypes
# Out:
# party
# DEMOCRAT       float64
# GREEN          float64
# LIBERTARIAN    float64
# OTHER          float64
# REPUBLICAN     float64
# WINNER           int32
# dtype: object

# %%
df2.to_sql('elections2020_clean', con = engine, if_exists = 'replace')

# %% [markdown]
# # POPOULATION_COUNTY DATABASE

# %%
pop_df=pd.read_csv(pop_to_load,engine='python',encoding='latin1')
pop_df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2019  \
# 0        4779736            4780125          4785437  ...          1.917501
# 1          54571              54597            54773  ...          4.847310
# 2         182265             182265           183112  ...         24.017829
# 3          27457              27455            27327  ...         -5.690302
# 4          22915              22915            22870  ...          1.385134
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015  \
# ...

# %%
pop_df.count()
# Out:
# SUMLEV                   3193
# REGION                   3193
# DIVISION                 3193
# STATE                    3193
# COUNTY                   3193
# STNAME                   3193
# CTYNAME                  3193
# CENSUS2010POP            3193
# ESTIMATESBASE2010        3193
# POPESTIMATE2010          3193
# POPESTIMATE2011          3193
# POPESTIMATE2012          3193
# POPESTIMATE2013          3193
# POPESTIMATE2014          3193
# POPESTIMATE2015          3193
# POPESTIMATE2016          3193
# POPESTIMATE2017          3193
# POPESTIMATE2018          3193
# POPESTIMATE2019          3193
# NPOPCHG_2010             3193
# NPOPCHG_2011             3193
# NPOPCHG_2012             3193
# NPOPCHG_2013             3193
# NPOPCHG_2014             3193
# NPOPCHG_2015             3193
# NPOPCHG_2016             3193
# NPOPCHG_2017             3193
# NPOPCHG_2018             3193
# NPOPCHG_2019             3193
# BIRTHS2010               3193
#                          ...
# ...

# %%
print(pop_df.columns)
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        ...
#        'RDOMESTICMIG2019', 'RNETMIG2011', 'RNETMIG2012', 'RNETMIG2013',
#        'RNETMIG2014', 'RNETMIG2015', 'RNETMIG2016', 'RNETMIG2017',
#        'RNETMIG2018', 'RNETMIG2019'],
#       dtype='object', length=164)

# %%
new_column_order= ["STNAME",
                   "CTYNAME",
                  "POPESTIMATE2019",
                  "INTERNATIONALMIG2019"]
pop_df=pop_df[new_column_order]
pop_df
# Out:
#          STNAME             CTYNAME  POPESTIMATE2019  INTERNATIONALMIG2019
# 0       Alabama             Alabama          4903185                  2772
# 1       Alabama      Autauga County            55869                   -16
# 2       Alabama      Baldwin County           223234                    80
# 3       Alabama      Barbour County            24686                    13
# 4       Alabama         Bibb County            22394                    10
# 5       Alabama       Blount County            57826                     6
# 6       Alabama      Bullock County            10101                    -1
# 7       Alabama       Butler County            19448                    18
# 8       Alabama      Calhoun County           113605                    14
# 9       Alabama     Chambers County            33254                     6
# 10      Alabama     Cherokee County            26196                    -3
# ...

# %%
pop_df.count()
# Out:
# STNAME                  3193
# CTYNAME                 3193
# POPESTIMATE2019         3193
# INTERNATIONALMIG2019    3193
# dtype: int64

# %%
pop_df['county_name'] = pop_df['CTYNAME'].str.split(' ').str[0]
pop_df['county_name'] = pop_df['county_name'].str.upper()

# %%
new_column_order= ["STNAME",
                   'county_name',
                  "POPESTIMATE2019",
                  "INTERNATIONALMIG2019"]
pop_df=pop_df[new_column_order]
pop_df
# Out:
#          STNAME county_name  POPESTIMATE2019  INTERNATIONALMIG2019
# 0       Alabama     ALABAMA          4903185                  2772
# 1       Alabama     AUTAUGA            55869                   -16
# 2       Alabama     BALDWIN           223234                    80
# 3       Alabama     BARBOUR            24686                    13
# 4       Alabama        BIBB            22394                    10
# 5       Alabama      BLOUNT            57826                     6
# 6       Alabama     BULLOCK            10101                    -1
# 7       Alabama      BUTLER            19448                    18
# 8       Alabama     CALHOUN           113605                    14
# 9       Alabama    CHAMBERS            33254                     6
# 10      Alabama    CHEROKEE            26196                    -3
# 11      Alabama     CHILTON            44428                    35
# 12      Alabama     CHOCTAW            12589                    -2
# ...

# %%
pop_clean_df= pop_df.drop_duplicates (subset= 'county_name', keep='last')

# %%
pop_clean_df[pop_clean_df['county_name']=='ALEUTIANS']
# Out:
#     STNAME county_name  POPESTIMATE2019  INTERNATIONALMIG2019
# 70  Alaska   ALEUTIANS             5634                    53

# %%
pop_clean_df
# Out:
#          STNAME    county_name  POPESTIMATE2019  INTERNATIONALMIG2019
# 0       Alabama        ALABAMA          4903185                  2772
# 1       Alabama        AUTAUGA            55869                   -16
# 6       Alabama        BULLOCK            10101                    -1
# 11      Alabama        CHILTON            44428                    35
# 17      Alabama        COLBERT            55241                    73
# 18      Alabama        CONECUH            12067                     1
# 19      Alabama          COOSA            10663                    13
# 21      Alabama       CRENSHAW            13772                     3
# 22      Alabama        CULLMAN            83768                    34
# 23      Alabama           DALE            49172                    18
# 28      Alabama         ETOWAH           102268                    37
# 31      Alabama         GENEVA            26271                    -7
# ...

# %%
pop_clean_df.to_csv("pop_clean.csv", index=False)

# %%
#Export to Database
pop_clean_df.to_sql('pop_clean', con = engine, index=False, if_exists = 'replace')

# %%
# final database

META_DATA = MetaData(bind=engine, reflect=True)

main_database = META_DATA.tables['main_database']
# Out:
# C:\Users\alelo\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SADeprecationWarning: The MetaData.reflect flag is deprecated and will be removed in a future release.   Please use the MetaData.reflect() method.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
main_database
# Out:
# Table('main_database', MetaData(bind=Engine(postgresql://ElectionTeam:***@final-data-project.cxtxzq2kyq9u.us-east-1.rds.amazonaws.com:5432/election_data)), Column('county_name', TEXT(), table=<main_database>), Column('POPESTIMATE2019', BIGINT(), table=<main_database>), Column('INTERNATIONALMIG2019', BIGINT(), table=<main_database>), Column('DEMOCRAT', DOUBLE_PRECISION(precision=53), table=<main_database>), Column('REPUBLICAN', DOUBLE_PRECISION(precision=53), table=<main_database>), Column('LIBERTARIAN', DOUBLE_PRECISION(precision=53), table=<main_database>), Column('GREEN', DOUBLE_PRECISION(precision=53), table=<main_database>), Column('OTHER', DOUBLE_PRECISION(precision=53), table=<main_database>), Column('WINNER', INTEGER(), table=<main_database>), Column('Debt_All', TEXT(), table=<main_database>), Column('Debt_Communities_Color', TEXT(), table=<main_database>), Column('Debt_Majorities_White', TEXT(), table=<main_database>), Column('Avg_Household_Income_All', BIGINT(), table=<main_
# ...

# %%
main_data_df =pd.read_sql_table("main_database", con= engine)

# %%
main_data_df
# Out:
#       county_name  POPESTIMATE2019  INTERNATIONALMIG2019  DEMOCRAT  \
# 0       ABBEVILLE            24527                   -11    4101.0
# 1          ACADIA            62045                    17    5443.0
# 2        ACCOMACK            32316                    30    7578.0
# 3             ADA           481587                    26  120539.0
# 4           ADAIR            22194                     3    7687.0
# 5           ADAMS            20220                     8  186146.0
# 6         ADDISON            36777                    20   15089.0
# 7           AIKEN           170872                   140   32275.0
# 8          AITKIN            15886                    -1    3607.0
# 9         ALACHUA           269043                   798   89704.0
# 10       ALAMANCE           169509                    67   38825.0
# 11        ALAMEDA          1671329                  8540  617659.0
# 12        ALAMOSA            16233                    -4    3759.0
# ...
